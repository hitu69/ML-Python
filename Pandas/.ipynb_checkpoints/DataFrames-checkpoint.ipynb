# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA','NY','AZ','TX']

# %%
mycolumns = ['Jan', 'Feb', 'Mar']

# %%
df = pd.DataFrame(mydata, index=myindex, columns=mycolumns)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
# file path

# %%
pwd
# Out:
# 'C:\\Users\\Hitesh\\Desktop\\ML_Algorithms_Python\\Pandas'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 9890-36BB
#
#  Directory of C:\Users\Hitesh\Desktop\ML_Algorithms_Python\Pandas
#
# 20-10-2023  01:05    <DIR>          .
# 19-10-2023  19:02    <DIR>          ..
# 19-10-2023  19:24    <DIR>          .ipynb_checkpoints
# 20-10-2023  01:05            35,049 DataFrames.ipynb
# 19-10-2023  19:21             7,788 Series.ipynb
# 19-10-2023  20:20             9,729 tips.csv
#                3 File(s)         52,566 bytes
#                3 Dir(s)  116,882,751,488 bytes free

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe().transpose()
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
#  ## Columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
mycols = ['total_bill','tip']
df[mycols]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df['tip_percentage'] = 100 * df['tip'] / df['total_bill']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
# df

# %%
df['price_per_person'] = df['total_bill'] / df['size']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.680765
#
#    price_per_person
# 0              8.49
# 1              3.45
# 2              7.00
# 3             11.84
# 4              6.15

# %%
df['price_per_person'] = np.round(df['total_bill'] / df['size'],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.680765
#
#    price_per_person
# 0              8.49
# 1              3.45
# 2              7.00
# 3             11.84
# 4              6.15

# %%
df.drop('tip_percentage', axis = 1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# [244 rows x 8 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_percentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
#      price_per_person
# 0                8.49
# 1                3.45
# 2                7.00
# 3               11.84
# 4                6.15
# ..                ...
# 239              9.68
# 240             13.59
# 241             11.34
# 242              8.91
# 243              9.39
#
# [244 rows x 9 columns]

# %%
df = df.drop('tip_percentage', axis = 1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# [244 rows x 8 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index('total_bill')

# %%
df.head()
# Out:
#              tip     sex smoker  day    time  size  price_per_person
# total_bill
# 16.99       1.01  Female     No  Sun  Dinner     2              8.49
# 10.34       1.66    Male     No  Sun  Dinner     3              3.45
# 21.01       3.50    Male     No  Sun  Dinner     3              7.00
# 23.68       3.31    Male     No  Sun  Dinner     2             11.84
# 24.59       3.61  Female     No  Sun  Dinner     4              6.15

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15

# %%
df = df.set_index('total_bill')

# %%
df.head()
# Out:
#              tip     sex smoker  day    time  size  price_per_person
# total_bill
# 16.99       1.01  Female     No  Sun  Dinner     2              8.49
# 10.34       1.66    Male     No  Sun  Dinner     3              3.45
# 21.01       3.50    Male     No  Sun  Dinner     3              7.00
# 23.68       3.31    Male     No  Sun  Dinner     2             11.84
# 24.59       3.61  Female     No  Sun  Dinner     4              6.15

# %%
df.iloc[0]
# Out:
# tip                   1.01
# sex                 Female
# smoker                  No
# day                    Sun
# time                Dinner
# size                     2
# price_per_person      8.49
# Name: 16.99, dtype: object

# %%
df.loc[16.99]
# Out:
# tip                   1.01
# sex                 Female
# smoker                  No
# day                    Sun
# time                Dinner
# size                     2
# price_per_person      8.49
# Name: 16.99, dtype: object

# %%
df.iloc[0:4]
# Out:
#              tip     sex smoker  day    time  size  price_per_person
# total_bill
# 16.99       1.01  Female     No  Sun  Dinner     2              8.49
# 10.34       1.66    Male     No  Sun  Dinner     3              3.45
# 21.01       3.50    Male     No  Sun  Dinner     3              7.00
# 23.68       3.31    Male     No  Sun  Dinner     2             11.84

# %%
df.loc[[16.99,23.68]]
# Out:
#              tip     sex smoker  day    time  size  price_per_person
# total_bill
# 16.99       1.01  Female     No  Sun  Dinner     2              8.49
# 23.68       3.31    Male     No  Sun  Dinner     2             11.84

# %%
df = df.drop(21.01, axis=0)

# %%
df.head()
# Out:
#              tip     sex smoker  day    time  size  price_per_person
# total_bill
# 16.99       1.01  Female     No  Sun  Dinner     2              8.49
# 10.34       1.66    Male     No  Sun  Dinner     3              3.45
# 23.68       3.31    Male     No  Sun  Dinner     2             11.84
# 24.59       3.61  Female     No  Sun  Dinner     4              6.15
# 25.29       4.71    Male     No  Sun  Dinner     4              6.32

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# tip                   1.01
# sex                 Female
# smoker                  No
# day                    Sun
# time                Dinner
# size                     2
# price_per_person      8.49
# Name: 16.99, dtype: object

# %%
df = pd.concat([df,pd.DataFrame([one_row])], axis=0)

# %%
df
# Out:
#         tip     sex smoker   day    time  size  price_per_person
# 16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 25.29  4.71    Male     No   Sun  Dinner     4              6.32
# ...     ...     ...    ...   ...     ...   ...               ...
# 27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 18.78  3.00  Female     No  Thur  Dinner     2              9.39
# 16.99  1.01  Female     No   Sun  Dinner     2              8.49
#
# [243 rows x 7 columns]
